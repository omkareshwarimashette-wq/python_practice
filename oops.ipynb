# %%
account_number = "ACC001"
account_holder = "arun"
account_balance = 1000

def deposit(amount):
    global account_balance
    account_balance += amount
    print(f"Deposited {amount}. New balance: {account_balance}")

def withdraw(amount):
    global balance
    if balance >= amount:
        balance -= amount
        print(f"withdrawn :{amount}.new balance :{balance}")
    else:
        print("Insufficient balance")

    def check_balance():
        print(f"Current balance: {account_balance}")

# %%
account_number1 = "ACC001"
account_holder1 = "arun"
account_balance1 = 1000

account_number2 = "ACC002"
account_holder2 = "varun"
account_balance2 = 2000


account_number3 = "ACC003"
account_holder3 = "kiran"
account_balance3 = 3000

account_number4 = "ACC004"
account_holder4 = "pavan"
account_balance4 = 1440

# %%
class BankAccount:
    def __init__(self, account_number, account_holder, account_balance):
        self.account_number = account_number
        self.account_holder = account_holder
        self.account_balance = account_balance

    def deposit(self, amount):
        self.account_balance += amount
        print(f"Deposited {amount}. New balance: {self.account_balance}")

    def withdraw(self, amount):
        if self.account_balance >= amount:
            self.account_balance -= amount
            print(f"Withdrawn: {amount}. New balance: {self.account_balance}")
        else:
            print("Insufficient balance")

    def check_balance(self):
        print(f"Current balance: {self.account_balance}")

# %%
account1 =BankAccount("accc001","ravi",10000)
account2 = BankAccount("acc002","sharath",20000)

# %%
account1.deposit(2000)
# Out:
# Deposited 2000. New balance: 12000

# %%
account1.withdraw(2000)
# Out:
# Withdrawn: 2000. New balance: 10000

# %%
account2.check_balance()
# Out:
# Current balance: 20000

# %%
### social media app
